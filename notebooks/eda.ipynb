# %% [markdown]
# # Loading data and clean it

# %% [markdown]
# To make import module in python available

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("../").resolve()))

# %%
from src.preprocess import clean_dataframe, clean_text

# %%
import pandas as pd
from pathlib import Path

# %%
pd.read_csv("/Users/ahmadabotrab/Desktop/arabic_sentiment_classification/data/Arabic_tweets_sentiment.csv")
# Out:
#                                          \ttext\tclass\tid
# 0        0\tانت فارقني انا تمام الشعب الاردني شعبي وجزء...
# 1        1\tانت ماقابلته الاردن رحت مقابلو مصر عار عليك...
# 2        2\tبعد طلبه فتح الحدود ومحاربة الاسرائيليين مم...
# 3        3\tوناااسه راح تصير اعماركم؟  ستشاهده خبر عظيم...
# 4        4\tممثل شهير يكشف مأساة عائلة زوجته غزة عمليهط...
# ...                                                    ...
# 2286123  2290409\tانت منصة اللي تغرد منها امريكيه \tPos...
# 2286124  2290410\tييييييي انت يخوي أنا اسف 🤦‍🤦‍🤦‍ قصدي ...
# 2286125  2290411\tلمزيد القتل والتدمير\tNegative\t"""17...
# 2286126  2290412\tيمكن السيسي يقاطع أبوههذا شرعا يجوز ت...
# 2286127  2290413\tموقف اردوغان خيب امال الناس وطلع شغل ...
#
# [2286128 rows x 1 columns]
